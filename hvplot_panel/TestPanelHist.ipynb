# %%
import hvplot_panel.panels as pa
import pandas as pd
import panel as pn
import os
from bokeh.sampledata.autompg import autompg
from hvplot.sample_data import us_crime, airline_flights
import hvplot.pandas

# %%
flights = airline_flights.to_dask().persist()
print(type(flights))
flights.head()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
#      year  month   day  dayofweek  dep_time  crs_dep_time  arr_time  \
# 0  2008.0   11.0  15.0        6.0    1411.0        1420.0    1535.0
# 1  2008.0   11.0  28.0        5.0    1222.0        1230.0    1345.0
# 2  2008.0   11.0  22.0        6.0    1414.0        1420.0    1540.0
# 3  2008.0   11.0  15.0        6.0    1304.0        1305.0    1507.0
# 4  2008.0   11.0  22.0        6.0    1323.0        1305.0    1536.0
#
#    crs_arr_time carrier  flight_num  ...  taxi_in  taxi_out  cancelled  \
# 0        1546.0   b'OO'      4391.0  ...      5.0      11.0        0.0
# 1        1356.0   b'OO'      4391.0  ...      5.0      15.0        0.0
# 2        1546.0   b'OO'      4391.0  ...      5.0      10.0        0.0
# 3        1519.0   b'OO'      4392.0  ...     10.0       9.0        0.0
# 4        1519.0   b'OO'      4392.0  ...      5.0      21.0        0.0
#
#    cancellation_code  diverted  carrier_delay weather_delay nas_delay  \
# ...

# %%
objects = {
    'y':list(autompg.columns),
    'by':list(autompg.columns)+[None]
}
defaults = {
    "y":['mpg'], 
    "by":['cyl', 'origin']
}
autompg.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %%
hist = pa.HistPanel(dataframe=autompg, objects=objects, defaults=defaults)
hist.panel().servable()
# Out:
# Row
#     [0] Column(margin=5, name='Param01325', width=300)
#         [0] StaticText(value='<b>HistPanel</b>')
#         [1] MultiSelect(name='Y', options=OrderedDict([('mpg', ...]), value=['mpg'])
#         [2] Select(name='By', options=OrderedDict([('mpg', ...]), value='mpg')
#         [3] Row(width_policy='max')
#             [0] LiteralInput(margin=(5, 0, 5, 10), name='Options axis', value=AxisOptionsPanel(colorbar=..., width=240)
#             [1] Toggle(align='center', button_type='primary', height_policy='fit', margin=(0, 0, 0, 10), max_height=30, max_width=20, name='⋮')
#     [1] ParamMethod(method)

# %%
import hvplot_panel.panels as pa
